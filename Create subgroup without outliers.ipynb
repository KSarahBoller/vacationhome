# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
df=pd.read_csv("/Users/sarahboller/Desktop/CF Achievement 6/02 Data/clean recent city merged 3182024.csv")

# %%
df.head()
# Out:
#   host_since  days Passed  host_total_listings_count  latitude  longitude  \
# 0   11/26/08         5591                          4  38.86339  -76.98889
# 1   12/12/08         5575                          5  38.91195  -77.00456
# 2   12/12/08         5575                          2  38.88719  -76.99472
# 3   12/30/08         5557                          4  38.90585  -76.94469
# 4    1/26/09         5530                          6  38.91217  -76.99249
#
#                property_type     room_type  accommodates  bathrooms  \
# 0       Private room in home  Private room             1        1.0
# 1  Private room in townhouse  Private room             2        1.0
# 2       Private room in home  Private room             1        1.5
# 3       Private room in home  Private room             2        1.0
# 4       Private room in home  Private room             1        3.0
#
#   Private/Shared/Unknown  ...  review_scores_rating  review_scores_accuracy  \
# ...

# %%
# Upper limit of price is 532.5. Deleting outliers.

# %%
df.loc[df['price']<532.5, 'price_not_outlier'] = 'Good'
# Out:
# /var/folders/xq/j07ql7ls565cz8lmytmw14b40000gn/T/ipykernel_96182/2917731842.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Good' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['price']<532.5, 'price_not_outlier'] = 'Good'

# %%
df.head()
# Out:
#   host_since  days Passed  host_total_listings_count  latitude  longitude  \
# 0   11/26/08         5591                          4  38.86339  -76.98889
# 1   12/12/08         5575                          5  38.91195  -77.00456
# 2   12/12/08         5575                          2  38.88719  -76.99472
# 3   12/30/08         5557                          4  38.90585  -76.94469
# 4    1/26/09         5530                          6  38.91217  -76.99249
#
#                property_type     room_type  accommodates  bathrooms  \
# 0       Private room in home  Private room             1        1.0
# 1  Private room in townhouse  Private room             2        1.0
# 2       Private room in home  Private room             1        1.5
# 3       Private room in home  Private room             2        1.0
# 4       Private room in home  Private room             1        3.0
#
#   Private/Shared/Unknown  ...  review_scores_accuracy  \
# ...

# %%
df_no_outliers=df[df['price_not_outlier']=="Good"]

# %%
df_no_outliers.head()
# Out:
#   host_since  days Passed  host_total_listings_count  latitude  longitude  \
# 0   11/26/08         5591                          4  38.86339  -76.98889
# 1   12/12/08         5575                          5  38.91195  -77.00456
# 2   12/12/08         5575                          2  38.88719  -76.99472
# 3   12/30/08         5557                          4  38.90585  -76.94469
# 5    1/13/09         5543                          4  38.91887  -77.04008
#
#                property_type        room_type  accommodates  bathrooms  \
# 0       Private room in home     Private room             1        1.0
# 1  Private room in townhouse     Private room             2        1.0
# 2       Private room in home     Private room             1        1.5
# 3       Private room in home     Private room             2        1.0
# 5         Entire rental unit  Entire home/apt             3        1.0
#
#   Private/Shared/Unknown  ...  review_scores_accuracy  \
# ...

# %%
df_no_outliers.drop(columns= ['price_not_outlier', 'reviews_per_month', 'host_total_listings_count'])
# Out:
#        host_since  days Passed   latitude  longitude  \
# 0        11/26/08         5591  38.863390 -76.988890
# 1        12/12/08         5575  38.911950 -77.004560
# 2        12/12/08         5575  38.887190 -76.994720
# 3        12/30/08         5557  38.905850 -76.944690
# 5         1/13/09         5543  38.918870 -77.040080
# ...           ...          ...        ...        ...
# 202279    3/31/16         2909  42.661069 -73.789731
# 202280    9/18/22          547  42.661443 -73.773513
# 202281   12/27/15         3004  42.640813 -73.774628
# 202282    8/25/14         3493  42.670961 -73.795139
# 202283   10/20/23          150  42.679082 -73.795049
#
#                       property_type        room_type  accommodates  bathrooms  \
# 0              Private room in home     Private room             1        1.0
# 1         Private room in townhouse     Private room             2        1.0
# 2              Private room in home     Private room             1        1.5
# ...

# %%
df_no_outliers.shape
# Out:
# (188466, 27)

# %%
df_no_outliers.dtypes
# Out:
# host_since                      object
# days Passed                      int64
# host_total_listings_count        int64
# latitude                       float64
# longitude                      float64
# property_type                   object
# room_type                       object
# accommodates                     int64
# bathrooms                      float64
# Private/Shared/Unknown          object
# beds                             int64
# price                            int64
# has_availability                object
# number_of_reviews                int64
# first_review                    object
# last_review                     object
# review_scores_rating           float64
# review_scores_accuracy         float64
# review_scores_cleanliness      float64
# review_scores_checkin          float64
# review_scores_communication    float64
# review_scores_location         float64
# review_scores_value            float64
# instant_bookable                object
# ...

# %%
df_no_outliers.to_csv("/Users/sarahboller/Desktop/CF Achievement 6/02 Data/clean recent city 4152024.csv")

# %%
df_upper_limit=df_no_outliers=df[df['price_outlier']=="outlier"]

# %%
df_upper_limit.shape
# Out:
# (13818, 28)

# %%
df_4=df_upper_limit.drop(columns= ['price_outlier', 'price_not_outlier', 'reviews_per_month', 'host_total_listings_count', 'has_availability', 'first_review', 'last_review','reviews_per_month'])

# %%
df_4.shape
# Out:
# (13818, 21)

# %%
df_4.to_csv("/Users/sarahboller/Desktop/CF Achievement 6/02 Data/upper limit price outliers 4152024.csv")
